# %% [markdown]
# ## Synthèse démarche de recherche de solution pour la résolution d'un problème technique

# %% [markdown]
# ##### *Besoin d'une requête SQL pouvant copier les données d'une colonne vers une autre, située dans une autre table*

# %% [markdown]
# ---

# %% [markdown]
# 01 - Recherche de la solution sur Google : "Copy data from one column to another column in a different table"

# %%
from IPython.display import Image
Image("./Snaps/Tuto_01.jpg", width = 800, height = 400)

# %% [markdown]
# ---

# %% [markdown]
# 02 - Le premier lien menant vers StackOverflow semble correspondre à mes besoins

# %%
from IPython.display import Image
Image("./Snaps/Tuto_02.jpg", width = 800, height = 400)

# %% [markdown]
# ---

# %% [markdown]
# 03 - Je teste la première réponse à la question (et la plus recommandée par les utilisateurs)

# %%
from IPython.display import Image
Image("./Snaps/Tuto_03.jpg", width = 800, height = 400)

# %% [markdown]
# ---

# %% [markdown]
# 04 - Ne marchant pas (problème concernant le positionnement du SELECT), je m'oriente vers la seconde réponse la plus recommandée

# %%
from IPython.display import Image
Image("./Snaps/Tuto_04.jpg", width = 800, height = 400)

# %% [markdown]
# ---

# %% [markdown]
# 05 - Adaptation du code à ma problématique, pas de message d'erreur à l'éxécution

# %%
from IPython.display import Image
Image("./Snaps/Tuto_05.jpg", width = 800, height = 400)

# %% [markdown]
# ---

# %% [markdown]
# 06 - Vérification de l'ajout dans PostGreSQL

# %%
from IPython.display import Image
Image("./Snaps/Tuto_06.jpg", width = 800, height = 400)

# %% [markdown]
# ---
