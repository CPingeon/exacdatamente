# %% [markdown]
# ## (02) Création des différents schémas et requêtes pour la visualisation

# %% [markdown]
# ---

# %% [markdown]
# ### 01 - Schéma UML des deux documents CSV "bruts"

# %%
from IPython.display import Image
Image("./Snaps/Schema_01.jpg")

# %% [markdown]
# ---

# %% [markdown]
# ### 02 - Schéma d'avancement du projet

# %%
from IPython.display import Image
Image("./Snaps/Schema_02.jpg")

# %% [markdown]
# ---

# %% [markdown]
# ### 03 - Schéma n°1 de la future BDD

# %%
from IPython.display import Image
Image("./Snaps/Schema_03.jpg")

# %% [markdown]
# ---

# %% [markdown]
# ### 04 - Schéma final de la future BDD

# %%
from IPython.display import Image
Image("./Snaps/Schema_04.jpg")

# %% [markdown]
# ---

# %% [markdown]
# ### 05 - Visualisation du diagramme ER de la BDD sur le logiciel DBeaver

# %%
from IPython.display import Image
Image("./Snaps/Schema_05.jpg")

# %% [markdown]
# ---

# %% [markdown]
# ### 06 - Maquette de l'app web de visualisation des données

# %%
from IPython.display import Image
Image("./Snaps/Schema_06.jpg")

# %% [markdown]
# ---

# %% [markdown]
# ### 07 - Requêtes pour la visualisation des données

# %% [markdown]
# #### _10 articles avec le plus de reviews_

# %% [markdown]
# #### _Nombre de produits en promotion ou non_

# %% [markdown]
# #### _Marques les plus représentées_

# %% [markdown]
# #### _10 articles les mieux notés avec plus de 30 notes_

# %% [markdown]
# #### _Couleurs les plus présentes_

# %% [markdown]
# #### _10 merchants les plus représentés_

# %% [markdown]
# #### _Pourcentage de produits disponibles ou non_

# %% [markdown]
# #### _Différentes currency_

# %% [markdown]
# #### _Différentes condition_

# %% [markdown]
# #### _Articles les plus chers en moyenne_

# %% [markdown]
# #### _Articles les moins chers en moyenne_

# %% [markdown]
# #### _Nombre de commentaires "Helpful"_

# %% [markdown]
# #### _Username avec le plus d'avis_

# %% [markdown]
# #### _Manufacturer les plus présents_

# %% [markdown]
# #### _Colonnes avec le plus de valeurs "Null"_

# %% [markdown]
# ---
